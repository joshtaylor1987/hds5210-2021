# %% [markdown]
# # Week 6 Exercises
#
# _McKinney 6.1_
#
# There are multiple ways to solve the problems below.  You can use any one of several approaches.  For example, you can read CSV files using Pandas or the csv module.  Your score won't depend on which modules you choose to use unless explicitly noted below, but your programming style will still matter.

# %% [markdown]
# ### 30.1 List of Allergies
#
# In the /data directory on the Jupyter server, there is a file called `allergies.json` that contains a list of patient allergies.  It is taken from sample data provided by the EHR vendor, Epic, here: https://open.epic.com/Clinical/Allergy
#
# Take some time to look at the structure of the file.  You can open it directly in Jupyter by clicking the _Home_ icon, then the _from_instructor_ folder, and then the _data_ folder.
#
# Within the file, you'll see that it is a dictionary with many items in it.  One of those items is called `entry` and that item is a list of things.  You can tell that because the item name is immediately followed by an opening square bracket, signifying the start of a list.  It's line 11 of the file: `  "entry": [`
#
# Write a function named `allergy_count(json_file)` that takes as one parameter the name of the JSON file and returns an integer number of entries in that file.  Your function should open the file, read the json into a Python object, and return how many items there are in the list of `entry`s.

# %%
import json
from pathlib import Path
HOME = str(Path.home())
ALLERGIES_FILE="/data/allergies.json"

# %%
### BEGIN SOLUTION
### END SOLUTION

# %%
### BEGIN SOLUTION
def allergy_count(json_file):
    with open(json_file) as f:
        allergies = json.load(f)
        
    return(len(allergies.get('entry')))
### END SOLUTION

# %%
allergy_count(ALLERGIES_FILE)
# Out:
# 4

# %%
assert type(allergy_count(ALLERGIES_FILE)) == int
assert allergy_count(ALLERGIES_FILE) == 4

# %% [markdown]
# ### 30.2 Number of Patients
#
# If you dig a little bit deaper into this list of allergies, you'll see that each result has a patient associated with it.  Create a funcation called `patient_count(json_file)` that will count how many unique patients we have in this JSON structure.

# %%
### BEGIN SOLUTION
### END SOLUTION

# %%
### BEGIN SOLUTION
def patient_count(json_file):
    patients = set()
    with open(json_file) as f:
        allergies = json.load(f)
        
    for entry in allergies.get('entry'):
        resource = entry.get('resource')
        patient = resource.get('patient')
        name = patient.get('display')
        patients.add(name)
        
    return patients
### END SOLUTION

# %%
patient_count(ALLERGIES_FILE)
# Out:
# {'Jason Argonaut', 'Paul Boal'}

# %% [markdown]
# ### 30.3 How Many Allergies per Patient
#
# Although each entry is a separate allergy, several of them are for the same patient.  Write a function called `allergy_per_patient(json_file)` that counts up how many allergies each patient has.

# %%
### BEGIN SOLUTION
### END SOLUTION

# %%
### BEGIN SOLUTION
def allergy_per_patient(json_file):
    patients = {}
    with open(json_file) as f:
        allergies = json.load(f)
        
    for entry in allergies.get('entry'):
        resource = entry.get('resource')
        patient = resource.get('patient')
        name = patient.get('display')
        patients[name] = patients.setdefault(name,0) + 1
        
    return patients
### END SOLUTION

# %%
allergy_per_patient(ALLERGIES_FILE)
# Out:
# {'Jason Argonaut': 3, 'Paul Boal': 1}

# %% [markdown]
# ### 30.4 Patient Allergies and Reaction
#
# You'll see in the file that each of the items in the `entry` list have several other attributes including a patient name, substance text representation, and a reaction manifestation.  Create a function named `allergy_list(json_file)` that will create an output list that has patient name, allergy, and reaction for each `entry`.  The actual result you should get will be:
#
# ```python
# [['Jason Argonaut', 'PENICILLIN G', 'Hives'],
#  ['Paul Boal', 'PENICILLIN G', 'Bruising'],
#  ['Jason Argonaut', 'SHELLFISH-DERIVED PRODUCTS', 'Itching'],
#  ['Jason Argonaut', 'STRAWBERRY', 'Anaphylaxis']]
# ```
#
# You'll notice that the reaction and the manifestation of that action are lists.  You only need to capture the first reaction and the first manifestation of the action.  That is, if there is a list of things, just output the first one.

# %%
import json

### BEGIN SOLUTION
def allergy_list(json_file):
    
    allergy_breakdown = []
    
    with open(json_file) as f:
        allergies = json.load(f)
    
    for entry in allergies.get('entry'):
        resource = entry.get('resource')
        name = resource.get('patient').get('display')
        substance = resource.get('substance').get('text')
        manifestations = resource.get('reaction')[0].get('manifestation')[0].get('text')
        
        allergy_breakdown.append([name, substance, manifestations])
        
    return allergy_breakdown
### END SOLUTION

# %%
output=[['Jason Argonaut', 'PENICILLIN G', 'Hives'],
 ['Paul Boal', 'PENICILLIN G', 'Bruising'],
 ['Jason Argonaut', 'SHELLFISH-DERIVED PRODUCTS', 'Itching'],
 ['Jason Argonaut', 'STRAWBERRY', 'Anaphylaxis']]

assert allergy_list(ALLERGIES_FILE) == output

# %% [markdown]
# ### 30.5 Allergy Reaction
#
# Write a function called `allergy_reaction(json_file,patient,substance)` that takes three parameter and returns the reaction that will happen if the patient takes the specified substance.  Solve this, in part, by calling your `allergy_list` function inside your new `allergy_reaction` function.
#
# If the substance is not found in the allergy list, the function should return None.

# %%
import json

### BEGIN SOLUTION
def allergy_reaction(json_file, patient, substance):
    
    manifestations = None
    
    with open(json_file) as f:
        allergies = json.load(f)
    
    for entry in allergies.get('entry'):
        resource = entry.get('resource')
        name = resource.get('patient').get('display')
        allergin = resource.get('substance').get('text')
        manifestations = resource.get('reaction')[0].get('manifestation')[0].get('text')
        
        if (name == patient and allergin == substance):
            return manifestations
    
### END SOLUTION

# %%
allergy_reaction(ALLERGIES_FILE, 'Paul Boal', 'PENICILLIN G')
# Out:
# 'Bruising'

# %%
assert allergy_reaction(ALLERGIES_FILE, 'Jason Argonaut', 'PENICILLIN G') == 'Hives'
assert allergy_reaction(ALLERGIES_FILE, 'Jason Argonaut', 'SHELLFISH-DERIVED PRODUCTS') == 'Itching'
assert allergy_reaction(ALLERGIES_FILE, 'Jason Argonaut', 'STRAWBERRY') == 'Anaphylaxis'
assert allergy_reaction(ALLERGIES_FILE, 'Jason Argonaut', 'PENICILLIN') == None
assert allergy_reaction(ALLERGIES_FILE, 'Paul Boal', 'PENICILLIN G') == 'Bruising'

# %% [markdown]
# ---
# ---
#
# # Stretch (Extra) Problems
#
# Work on either of the stretch problems below can earn you up to 25 free points toward the midterm assignment.  That is, if you complete one of these extra problems successfully, you can skip 1 of the problems that will appear on the midterm exam coming up next week.
#
# The midterm will be distribute this Saturday 3/13.
#
# This assignment is due on Sunday 3/14.  If you are trying for one of these extra problems Slack me, and I'll provide you feedback on how you did on these before end of day Monday 3/15.  That way you can choose what to complete on the midterm.

# %% [markdown]
# ---
# ---
#
# ### STRETCH for March 2021 - For those looking for an additional challenge
#
# As I've mentioned in class, CMS is now enforcing a rule around price transparency.  Every facility that take Medicare payments is required to publish a "machine readable" file with it's pricing infomration for a number of common procedures across all of the payers they work with.  There are two examples of such files in the `/data/` directory: `whiteriver.json` and `saline.xml`.
#
# If you want to compare contracted prices across these two hospitals, you'll need to read in the information from both of those files into some kind of data structure, then merge the data together from those two files.  See what you can do.
#
# See if you can create an output file that has the following fields:
# * HOSPITAL
# * PROCEDURE_CODE
# * PAYER
# * AMOUNT
#
# If you choose to work on this, you may get stuck at some point and you won't know if you're _doing it right_. Make some assumptions. Document your questions in this notebook.

# %%
import json
WHITERIVER_FILE="/data/whiteriver.json"

def output_json_table(json_file):
    
    pricing = []
    
    with open(json_file) as f:
        price_matrix = json.load(f)
    
    for item in price_matrix.get('root'):
        HOSPTIAL = price_matrix.get('root').get('HospitalorFacilityName')
        
        for charge in price_matrix.get('root').get('StandardCharges'):
            PROCEDURE_CODE = charge.get('ProcedureCode')
            PAYER = []
            for payer in charge:
                if payer not in ['Description',
                                 'ProcedureCode',
                                 'Modifier',
                                 'RevenueCode',
                                 'MSDRG',
                                 'NDC',
                                 'InpatientGrossCharge',
                                 'OutpatientGrossCharge',
                                 'EmergencyRoomGrossCharge',
                                 'MSDRGAverageGrossCharge',
                                 'DiscountedCashPrice',
                                 'MinimumNegotiatedCharge',
                                 'MaximumNegotiatedCharge']:
                    P = payer
                    AMOUNT = charge.get(payer)
                    PAYER.append({'PAYER': P, "AMOUNT" : AMOUNT})
            pricing.append({'HOSPTIAL' : HOSPTIAL, 'PROCEDURE_CODE' : PROCEDURE_CODE,})
            pricing.append([PAYER])

    return pricing

# %%
output_json_table(WHITERIVER_FILE)
# Out:
# [{'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '00170'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '8400.9904'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '8400.9904'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '8400.9904'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '8400.9904'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '5346.0848'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '5346.0848'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '8400.9904'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '8400.9904'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '00220'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '18.4800'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '18.4800'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '18.4800'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '18.4800'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '11.7600'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '11.7600'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '18.4800'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '18.4800'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '01996'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '224.4000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '224.4000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '224.4000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '224.4000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '142.8000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '142.8000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '224.4000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '224.4000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10004'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '478.7200'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '478.7200'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '478.7200'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '478.7200'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '304.6400'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '304.6400'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '478.7200'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '478.7200'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10005'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '1455.4400'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '1455.4400'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '609.74'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10006'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '786.8000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '786.8000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10007'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '786.8000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '786.8000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '609.74'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10008'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '786.8000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '786.8000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10009'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '786.8000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '786.8000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '609.74'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10010'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '786.8000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '786.8000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10011'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '786.8000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '786.8000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '609.74'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10012'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '786.8000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '786.8000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '1236.4000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10021'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '1455.4400'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '1455.4400'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '2287.1200'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '339.04'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10030'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '5073.7368'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '5073.7368'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '5073.7368'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '5073.7368'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '3228.7416'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '3228.7416'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '5073.7368'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '5073.7368'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '609.74'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10060'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '10126.1160'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '10126.1160'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '10126.1160'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '10126.1160'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '6443.8920'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '6443.8920'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '10126.1160'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '10126.1160'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '176.02'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10061'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '415.3600'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '415.3600'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '415.3600'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '415.3600'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '264.3200'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '264.3200'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '415.3600'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '415.3600'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '339.04'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10120'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '644.1600'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '644.1600'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '644.1600'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '644.1600'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '409.9200'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '409.9200'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '644.1600'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '644.1600'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '339.04'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10140'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '7043.5288'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '7043.5288'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '7043.5288'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '7043.5288'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '4482.2456'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '4482.2456'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '7043.5288'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '7043.5288'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '1379.32'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '10160'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1606.8800'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1606.8800'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1606.8800'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1606.8800'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '1022.5600'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '1022.5600'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '339.04'},
# ...
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '339.04'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '528.8800'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '528.8800'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '339.04'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '17110'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '277.2000'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '277.2000'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '277.2000'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '277.2000'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '176.4000'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '176.4000'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '277.2000'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '277.2000'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '176.02'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '17250'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '388.0800'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '388.0800'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '388.0800'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '388.0800'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '246.9600'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '246.9600'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '176.02'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '388.0800'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '388.0800'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '176.02'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '19000'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '4033.0400'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '4033.0400'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '4033.0400'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '4033.0400'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '2566.4800'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '2566.4800'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '609.74'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '4033.0400'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '4033.0400'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '609.74'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '19001'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '1185.5800'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '1185.5800'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '1185.5800'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '1185.5800'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '754.4600'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '754.4600'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '0'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '1185.5800'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '1185.5800'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '0'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '19020'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '621.2800'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '621.2800'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '621.2800'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '621.2800'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '395.3600'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '395.3600'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '621.2800'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '621.2800'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '1379.32'}]],
#  {'HOSPTIAL': 'White River Medical Center', 'PROCEDURE_CODE': '19081'},
#  [[{'PAYER': 'AARPMedicareManagedCare_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'ADVANTRAFREEDOM_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'AETNA_Outpatient', 'AMOUNT': '2719.4200'},
#    {'PAYER': 'AETNA_EmergencyRoom', 'AMOUNT': '2719.4200'},
#    {'PAYER': 'AETNAMEDICAREADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'AETNAOTHER_Outpatient', 'AMOUNT': '2719.4200'},
#    {'PAYER': 'AETNAOTHER_EmergencyRoom', 'AMOUNT': '2719.4200'},
#    {'PAYER': 'Allwell_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'Amerigroup_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'ARKANSASCOMMUNITYCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'Cigna-Healthspring_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'GOLDENRULEINSCO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANACHOICEPPO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANAGOLD(MCRHMO)_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'HUMANAGOLDPFFS_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDICARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MedicareAdvantageOther_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MedicareRailroad_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDIPAK_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MEDIPAKADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'MVPHEALTHCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'PYRAMID/MCRHMO_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'QUALCHOICE_Outpatient', 'AMOUNT': '1730.5400'},
#    {'PAYER': 'QUALCHOICE_EmergencyRoom', 'AMOUNT': '1730.5400'},
#    {'PAYER': 'SECUREHORIZONS_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'STERLINGOPTIONONE,STER_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TributeHealthPlan_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREEAST_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREFORLIFE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'TRICAREWEST_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UMR_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHCOFRIVERVALLEY_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCAREADVANTAGE_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+GA_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCARECHOICE+UT_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UNITEDHEALTHCAREOTHER_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'UnitedHealthcareSharedServ._OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'VACHAMPVA_OPPS', 'AMOUNT': '1379.32'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_Outpatient', 'AMOUNT': '2719.4200'},
#    {'PAYER': 'WEBTPAAetnaNonemployee_EmergencyRoom', 'AMOUNT': '2719.4200'},
#    {'PAYER': 'WELLCAREHEALTHPLANS_OPPS', 'AMOUNT': '1379.32'}]]]

# %%
from lxml import objectify 
import xml.etree.ElementTree as ET 
SALINE_FILE = "/data/saline.xml"

def output_xml_table(xml_file):
    
    with open(xml_file) as f1:
        xml = objectify.parse(f1)

    tree = ET.parse(xml_file)
    price = xml.getroot()
    
#     for child in price:
#         print(child.tag + " : " + str(child.attrib))
        
#     ns={"fhir": "http://hl7.org/fhir"}

#     for address in patient.findall('fhir:address', namespa):
#         city = address.find('fhir:city', namespaces=ns)
#         print("Address City: " + city.attrib.get('value'))

    # create element tree object 
    tree = ET.parse(xml_file) 
  
    # get root element 
    root = tree.getroot() 
  
    # create empty list for news items 
    pricing = [] 
  
    # iterate news items 
    for item in price.findall('./facility/name'): 
  
        # empty news dictionary 
        hosptial = {} 
  
        # iterate child elements of item 
        for child in name: 
  
            # special checking for namespace object content:media 
            if child.tag == '{http://search.yahoo.com/mrss/}content': 
                news['media'] = child.attrib['url'] 
            else: 
                news[child.tag] = child.text.encode('utf8') 
  
        # append news dictionary to news items list 
        pricing.append(hospital) 
        print(pricing)

# %%
output_xml_table(SALINE_FILE)

# %% [markdown]
# I feel confident in the JSON table. I just feel that I have run out of time on trying to work through the XML file. In addition to parsing the XML file in the same dictionary style as I did to the JSON file I would need to add a leading 00 to the procedure code in order to better enable cross referencing.

# %% [markdown]
# ---
# ---
#
# ### STRETCH from March 2020 - For those looking for an additional challenge
#
# The Coronavirus is creating quite the stir right now.  There are some sources suggesting that trends show it is going to be significantly more serious than SARS was back in the 2002 timeframe.  Here's one visualization trying to demonstrate that: https://www.reddit.com/r/China_Flu/comments/ev2b4v/i_updated_some_charts_comparing_this_outbreak/
#
# Someone on Kaggle has generously already compiled a dataset based on information from Johns Hopkins about the Coronavirus outbreak.  https://www.kaggle.com/brendaso/2019-coronavirus-dataset-01212020-01262020  Create a Kaggle account, if you don't already have one.  Download this data set and then upload it to your Jupyter Home folder.  (The "up arrow" button is for uploading a file.)
#
# Use Python's built-in `csv` module to read the data from this file and generate the following information: **what are the total confirmed cases in all of Mainland China as of the latest information in the data set?**  Some important things to note:
# * Each entry for a given city has the **cumulative** number of cases.  So that column is not additive (it cannot be summed).  You'll have to find a way to filter your data for the last day for each city, then total those up.
# * If you choose to parse the date column, you will want to lookup how to do that using Python's `datetime` module.  Especially the `strptime` function.  https://docs.python.org/3/library/datetime.html#strftime-strptime-behavior  Hint: you can parse a date string in the format 2/17/2020 using the code below.  This link will tell you what things like `%m` and `%Y` mean.
#
# ```
# from datetime import datetime
# d = datetime.strptime('2/17/2020', '%m/%d/%Y')
# ```
#
# If you want to take this another step, **create a list of tuples that contain (observate date, total confirmed) totalled over all locations represented in the data**

# %% [markdown]
# ---
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Save this note with Ctrl-S (or Cmd-S)
# 2. Skip down to the last command cell (the one starting with `%%bash`) and run that cell.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %%
assert False, "DO NOT REMOVE THIS LINE"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-cef8011cb395> in <module>
# ----> 1 assert False, "DO NOT REMOVE THIS LINE"
#
# AssertionError: DO NOT REMOVE THIS LINE

# %% [markdown]
# ---

# %%
# %%bash
# git pull
# git add week06_assignment_2.ipynb
# git commit -a -m "Submitting the week 6 programming assignment"
# git push

# %% [markdown]
# ---
#
# If the message above says something like _Submitting the week 6 programming assignment_ or _Everything is up to date_, then your work was submitted correctly.
